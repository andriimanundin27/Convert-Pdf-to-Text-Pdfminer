# %%
# !pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading https://files.pythonhosted.org/packages/8a/fd/6e8746e6965d1a7ea8e97253e3d79e625da5547e8f376f88de5d024bacb9/pdfminer.six-20181108-py2.py3-none-any.whl (5.6MB)
#     100% |████████████████████████████████| 5.6MB 5.7MB/s
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.6/dist-packages (from pdfminer.six) (2.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from pdfminer.six) (1.11.0)
# Collecting pycryptodome (from pdfminer.six)
#   Downloading https://files.pythonhosted.org/packages/ab/bc/589fbae48c0969719f28b862d979f8e9d4d1e08bb7f68ad7a495b1ba2d54/pycryptodome-3.7.2-cp36-cp36m-manylinux1_x86_64.whl (7.5MB)
#     100% |████████████████████████████████| 7.5MB 3.9MB/s
# Installing collected packages: pycryptodome, pdfminer.six
# Successfully installed pdfminer.six-20181108 pycryptodome-3.7.2

# %%
#Authenfikasi Akun Gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Pindah direktori/path pada Gdrive
# %cd /content/drive/'My Drive'/'Pindahan Skripsi'
# Out:
# /content/drive/My Drive/Pindahan Skripsi

# %%
#Cek isi dari direktori/path Gdrive
# !ls
# Out:
#  bi.csv
#  bit.csv
#  biterm.csv
#  biterms.csv
#  BTMkoreksikata.csv
# 'download online.ipynb'
#  foo.csv
#  idwiki-latest-pages-meta-current.xml.bz2
#  idwiki-latest-pages-meta-current.xml.bz2.1
#  idwiki-latest-pages-meta-current.xml.bz2.2
#  JKN.csv
#  JKN.xlsx
#  kata-dasar.txt
#  kbbi.pdf
#  kbbi.txt
#  koreksi.csv
#  koreksi.gsheet
#  koreksikata.csv
#  koreksikata.gsheet
#  newkoreksi.csv
#  newkoreksiv2.csv
# 'newkoreksiv2fix (1).gsheet'
#  newkoreksiv2fix.csv
#  newkoreksiv2fix.gsheet
#  newkoreksiv2.gsheet
# 'pdf extract.ipynb'
# 'proposal andri imanudin.docx'
# 'proposal andri imanudin (FIX).docx'
# 'proposal fix'
# 'Skripsi ku ayee.ipynb'
#  stoplist.txt
#  wikipedia.xml

# %%
import io
 
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage

# %%
def extract_text_from_pdf(pdf_path):
    resource_manager = PDFResourceManager()
    fake_file_handle = io.StringIO()
    converter = TextConverter(resource_manager, fake_file_handle)
    page_interpreter = PDFPageInterpreter(resource_manager, converter)
 
    with open(pdf_path, 'rb') as fh:
        for page in PDFPage.get_pages(fh, 
                                      caching=True,
                                      check_extractable=True):
            page_interpreter.process_page(page)
 
        text = fake_file_handle.getvalue()
 
    # close open handles
    converter.close()
    fake_file_handle.close()
 
    if text:
        return text

# %%
pdftotext=extract_text_from_pdf('kbbi.pdf')
print(pdftotext)

# %%
pdftotext
# Out:
# '\x0c  KAMUSBAHASA INDONESIA       \x0c KAMUSBAHASA INDONESIA PUSAT BAHASA DEPARTEMEN PENDIDIKAN NASIONAL JAKARTA, 2008 \x0c                  499.213 KAM  Kamus Bahasa Indonesia/Tim Penyusun    k       Kamus Pusat Bahasa.        Jakarta: Pusat Bahasa, 2008        xvi, 1826 hlm.; 21,5 cm       ISBN 978-979-689-779-1              BAHASA INDONESIA - KAMUS \x0c TIM REDAKSI KAMUS BAHASA INDONESIA Pemimpin Redaksi Dendy Sugono PenyeliaSugiyono Yeyen Maryani Redaksi Pelaksana KetuaMeity Taqdir Qodratillah AnggotaCormentyna Sitanggang, Menuk Hardaniwati Dora Am